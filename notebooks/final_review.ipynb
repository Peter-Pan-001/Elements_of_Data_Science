# %% [markdown]
# # # Elements of Data Science: A First Course
#
# # COMS W4995 007 2018 3
#
#
# ## Final Review

# %% [markdown]
# This is intended as a guide and may not be inclusive.
#
# Material considered fair for the exam is anything from class, the slides or the readings.
#
# Note sheet allowed: 1 8x11in paper both sides

# %% [markdown]
# ## Topics from the Midterm (less focus, but still recall)

# %% [markdown]
# - Introduction to Data Science problems and tools
#     - Data Science workflow
#     - virtual environments
#     - Ipython Notebook
#
#
# - Data Processing
#     - data types
#     - dataset structure
#     - numpy
#         - arrays
#         - matrices
#         - indexing
#     - pandas
#         - series
#         - dataframes
#         - data description
#         - indexing
#         - grouping
#         - load from csv
#     - transforming data
#         - missing values/imputing
#         - concatinate, append and join
#         - setting indices
#         - setting columns
#         - aggregation and summarization
#
#
# - Data Exploration and Visualization
#     - assert
#     - pivot and melt
#     - single variable statistics
#         - mean
#         - variance
#         - quantiles
#     - plotting (why and how)
#         - histograms
#         - box plots
#         - scatter plots
#     - correlation
#
#
# - Statistical Modeling and Hypothesis Testing
#     - A/B Tests
#     - Hypothesis Testing
#     - Permutation Tests
#     - p-values
#         - one-tailed vs two-tailed tests
#     - Calculating power and number of samples needed
#     - Multi-Armed Bandit
#
#
# - Classification and Regression
#     - supervised learning
#     - sklearn model commands
#     - (know models conceptually)
#     - (know differences between models)
#     - regression
#         - simple linear regression
#         - polynomial regression
#         - multivariate regression
#     - classification
#         - k Nearest Neighbor
#         - logistic regression
#         - naive bayes
#         - decision trees
#         - (know what an ensemble is)
#             - random forest
#             - gradient boost
#         - svm (very generally)
#         - neural networks (very generally)
#
#
# - Feature Engineering and Application: Natural Language Processing
#     - dealing with duplicates
#     - creating dummies
#     - outliers
#         - causes
#         - detection
#         - dealing with
#     - binning
#     - pipelines
#     - zscore/scaling/standardization/normalization
#     - dummy variables/one-hot-encoding
#     - imputing/mean/median
#     - natural language processings
#          - document, corpus
#          - tokenization
#          - bag of words
#          - term/document frequency
#          - tf-idf
#          - n-grams

# %% [markdown]
# ## New Topics (Most of the focus)

# %% [markdown]
# - Feature Selection, Model Evaluation and Selection
#     - Regression
#         - RMSE
#         - Residuals
#         - R^2
#     - Bias, Variance tradeoff
#     - Overfitting and Underfitting
#         - the Train/Test split
#         - Validation Curve
#     - Regularization
#         - Ridge
#         - LASSO
#         - ElasticNet
#     - Cross Validation
#     - Grid Search
#     - Classification
#         - Accuracy and Error
#         - Confusion Matrix
#         - Precision vs. Recall
#         - ROC and AUC
#     - Feature Selection
#         - Univariate
#         - Stepwise
#         - Model Based
#
#
#
# - Project Reporting and Application: Time Series
#     - Project Reporting
#         - Tools we've used
#         - Options for plotting
#     - Time Series
#         - Resampling
#             - Upsampling
#             - Downsampling
#         - Shifting
#         - Windowing
#
#
#
# - Dimensionality Reduction and Application: Image Recognition
#     - Dimensionality Reduction
#         - Why do it
#         - PCA
#
#
# - Clustering, Topic Modeling and Recommendation Engine
#     - Clustering
#         - k-Means
#             - choosing k
#             - Within Cluster Sum of Squared Error
#         - Hierarchical Agglomerative Clustering (HAC)
#             - linkage options (complete, average, ward)
#             - dendrograms
#     - Topic Modeling
#         - Why do it
#         - What you get from LDA
#
#
# - Recommendation Engines
#     - Collaborative Filtering
#     - Content-Based
#     - Precision @N, Recall @N
#
#
# - Data Management
#     - Structured vs Unstructured Data
#     - Flatfile vs Relational vs NoSQL
#     - Basic SQL commands (SELECT,FROM,WHERE)
#     - Normalization
